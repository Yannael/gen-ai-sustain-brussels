# %%
# !pip install openai

from openai import OpenAI
from pathlib import Path

client = OpenAI(api_key="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")

# %% [markdown]
# # 🗣️ Converting Text to Speech with OpenAI
#
# With OpenAI's text-to-speech (TTS) feature, you can turn any piece of text into spoken audio using different AI voices.
#
# In this example, we use the **`gpt-4o-mini-tts`** model (the last one) to generate speech from text.

# %%
from pathlib import Path

# Directly specify the filename
speech_file_path = Path("speech.mp3")

with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="fable",
    input="I'm here today to take a training course on how to use LLMs.",
    instructions="Use a professional and positive tone.",
) as response:
    response.stream_to_file(speech_file_path)

# %% [markdown]
# The `voice` parameter lets you choose **which AI voice** will speak the text when generating the audio.
#
# OpenAI provides several different voices, each with a unique style and tone.
#
# #### 🎧 Available voices:
# - `alloy`
# - `ash`
# - `ballad`
# - `coral`
# - `echo`
# - `fable`
# - `onyx`
# - `nova`
# - `sage`
# - `shimmer`
# - `verse`
#
#
# Once the speech is saved as an MP3 file, we can listen to it directly using the code below:

# %%
from IPython.display import Audio
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 🌍 Multilingual Text-to-Speech
#
# OpenAI's text-to-speech also works with **many other languages**, not just English.
# The model automatically detects the language based on your input text.
#
# In the example below, we ask the model to speak in **French**:

# %%
from pathlib import Path

# Directly specify the filename
speech_file_path = Path("speech_fr.mp3")

with client.audio.speech.with_streaming_response.create(
    model="gpt-4o-mini-tts",
    voice="coral",
    input="Je suis ici aujourd'hui pour suivre une formation sur l'utilisation desiugjhgjhs.",
    instructions="Utilisez un ton professionnel et positif.",
) as response:
    response.stream_to_file(speech_file_path)

# %%
from IPython.display import Audio
Audio("speech_fr.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 🎙️ Transcribing Audio to Text (Speech-to-Text)
#
# OpenAI also lets you convert **spoken audio into written text** — this is called **speech-to-text** or **transcription**.
#
# In this example, we take the audio file `speech.mp3` (generated earlier) and transcribe what it says:

# %%
transcript = client.audio.transcriptions.create(
  model="gpt-4o-transcribe",
  file=open("speech.mp3", "rb")
)

transcript.text
# Out:
# "I'm here today to take a training course on how to use LLMs."

# %% [markdown]
# ---
#
# ## ✏️ Practice Questions
#
# 1. **Change the voice**
#    Modify the text-to-speech code to use a different voice from the list (e.g., `"shimmer"` or `"nova"`).
#
# 2. **Transcribe the French audio**
#    Use the `speech_fr.mp3` file (generated earlier in French) and transcribe it using the same method as for the English audio.
